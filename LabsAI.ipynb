# %% [markdown]
# # Prácticas de Computer Vision

# %%
pip install azure-cognitiveservices-vision-computervision
# Out:
# Requirement already satisfied: azure-cognitiveservices-vision-computervision in c:\users\jairm\appdata\local\programs\python\python310\lib\site-packages (0.9.0)
# Requirement already satisfied: azure-common~=1.1 in c:\users\jairm\appdata\local\programs\python\python310\lib\site-packages (from azure-cognitiveservices-vision-computervision) (1.1.28)
# Requirement already satisfied: msrest>=0.5.0 in c:\users\jairm\appdata\local\programs\python\python310\lib\site-packages (from azure-cognitiveservices-vision-computervision) (0.7.1)
# Requirement already satisfied: isodate>=0.6.0 in c:\users\jairm\appdata\local\programs\python\python310\lib\site-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-computervision) (0.6.1)
# Requirement already satisfied: azure-core>=1.24.0 in c:\users\jairm\appdata\local\programs\python\python310\lib\site-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-computervision) (1.24.1)
# Requirement already satisfied: requests~=2.16 in c:\users\jairm\appdata\local\programs\python\python310\lib\site-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-computervision) (2.28.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jairm\appdata\local\programs\python\python310\lib\site-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-computervision) (2022.6.15)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in c:\users\jairm\appdata\local\programs\python\python310\lib\site-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-computervision) (1.3.1)
# Requirement already satisfied: typing-extensions>=4.0.1 in c:\users\jairm\appdata\local\programs\python\python310\lib\site-packages (from azure-core>=1.24.0->msrest>=0.5.0->azure-cognitiveservices-vision-computervision) (4.2.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\jairm\appdata\local\programs\python\python310\lib\site-packages (from azure-core>=1.24.0->msrest>=0.5.0->azure-cognitiveservices-vision-computervision) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jairm\appdata\local\programs\python\python310\lib\site-packages (from requests~=2.16->msrest>=0.5.0->azure-cognitiveservices-vision-computervision) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jairm\appdata\local\programs\python\python310\lib\site-packages (from requests~=2.16->msrest>=0.5.0->azure-cognitiveservices-vision-computervision) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\jairm\appdata\local\programs\python\python310\lib\site-packages (from requests~=2.16->msrest>=0.5.0->azure-cognitiveservices-vision-computervision) (2.0.12)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\jairm\appdata\local\programs\python\python310\lib\site-packages (from requests-oauthlib>=0.5.0->msrest>=0.5.0->azure-cognitiveservices-vision-computervision) (3.2.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'c:\Users\jairm\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\jairm\appdata\local\programs\python\python310\lib\site-packages (3.5.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\jairm\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\jairm\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\jairm\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\jairm\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jairm\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\jairm\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.22.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jairm\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.33.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\jairm\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (9.1.1)
# Requirement already satisfied: six>=1.5 in c:\users\jairm\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'c:\Users\jairm\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
# Establecemos nuestras credenciales.
key = '1d4235aed7804f4a986fdfc6534c2c7f'
endpoint = 'https://cv-dr-lab0.cognitiveservices.azure.com/'

# %%
# Conectamos con Azure
from azure.cognitiveservices.vision.computervision import ComputerVisionClient
from msrest.authentication import CognitiveServicesCredentials

client = ComputerVisionClient(endpoint, CognitiveServicesCredentials(key))

# %%
import vision
import os

# %matplotlib inline

# Obtenemos la imagen
image_path = './data/vision/Personas.jpg'

image_stream = open(image_path, "rb")
description = client.describe_image_in_stream(image_stream)
print(description)

vision.show_image_caption(image_path, description)
# Out:
# {'additional_properties': {}, 'tags': ['person', 'ground', 'outdoor', 'woman', 'food', 'dessert'], 'captions': [<azure.cognitiveservices.vision.computervision.models._models_py3.ImageCaption object at 0x000001940927E1D0>], 'request_id': '74d3c8be-8eee-44dd-acad-7ccb834da4ec', 'metadata': <azure.cognitiveservices.vision.computervision.models._models_py3.ImageMetadata object at 0x000001940927F5E0>, 'model_version': '2021-05-01'}

# %%
image_path = './data/vision/persona2.jpg'

image_stream = open(image_path, "rb")
description = client.describe_image_in_stream(image_stream)

vision.show_image_caption(image_path, description)

# %%
# Obtenemos la imagen
image_path = './data/vision/Personas.jpg'

features = ['Description', 'Tags', 'Adult', 'Objects', 'Faces']

image_stream = open(image_path, "rb")
analysis = client.analyze_image_in_stream(image_stream, visual_features=features)

vision.show_image_analysis(image_path, analysis)

# %% [markdown]
# ## FaceAPI

# %%
pip install azure-cognitiveservices-vision-face
# Out:
# Collecting azure-cognitiveservices-vision-face
#   Downloading azure_cognitiveservices_vision_face-0.6.0-py2.py3-none-any.whl (67 kB)
#      -------------------------------------- 67.7/67.7 KB 522.0 kB/s eta 0:00:00
# Requirement already satisfied: azure-common~=1.1 in c:\users\jairm\appdata\local\programs\python\python310\lib\site-packages (from azure-cognitiveservices-vision-face) (1.1.28)
# Requirement already satisfied: msrest>=0.5.0 in c:\users\jairm\appdata\local\programs\python\python310\lib\site-packages (from azure-cognitiveservices-vision-face) (0.7.1)
# Requirement already satisfied: requests~=2.16 in c:\users\jairm\appdata\local\programs\python\python310\lib\site-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-face) (2.28.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jairm\appdata\local\programs\python\python310\lib\site-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-face) (2022.6.15)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in c:\users\jairm\appdata\local\programs\python\python310\lib\site-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-face) (1.3.1)
# Requirement already satisfied: azure-core>=1.24.0 in c:\users\jairm\appdata\local\programs\python\python310\lib\site-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-face) (1.24.1)
# Requirement already satisfied: isodate>=0.6.0 in c:\users\jairm\appdata\local\programs\python\python310\lib\site-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-face) (0.6.1)
# Requirement already satisfied: typing-extensions>=4.0.1 in c:\users\jairm\appdata\local\programs\python\python310\lib\site-packages (from azure-core>=1.24.0->msrest>=0.5.0->azure-cognitiveservices-vision-face) (4.2.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\jairm\appdata\local\programs\python\python310\lib\site-packages (from azure-core>=1.24.0->msrest>=0.5.0->azure-cognitiveservices-vision-face) (1.16.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\jairm\appdata\local\programs\python\python310\lib\site-packages (from requests~=2.16->msrest>=0.5.0->azure-cognitiveservices-vision-face) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jairm\appdata\local\programs\python\python310\lib\site-packages (from requests~=2.16->msrest>=0.5.0->azure-cognitiveservices-vision-face) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jairm\appdata\local\programs\python\python310\lib\site-packages (from requests~=2.16->msrest>=0.5.0->azure-cognitiveservices-vision-face) (3.3)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\jairm\appdata\local\programs\python\python310\lib\site-packages (from requests-oauthlib>=0.5.0->msrest>=0.5.0->azure-cognitiveservices-vision-face) (3.2.0)
# Installing collected packages: azure-cognitiveservices-vision-face
# Successfully installed azure-cognitiveservices-vision-face-0.6.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'c:\Users\jairm\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
key = '527f7fe72b9449168d5691c933d75753'
endpoint = 'https://face-dr-lab02.cognitiveservices.azure.com/'

# %%
# Conectamos con Azure
from azure.cognitiveservices.vision.face import FaceClient
from msrest.authentication import CognitiveServicesCredentials

client = FaceClient(endpoint, CognitiveServicesCredentials(key))

# %%
import faces
import os
# %matplotlib inline

# %%
image_path = './data/vision/personas.jpg'
image_stream = open(image_path, "rb")

detected_faces = client.face.detect_with_stream(image_stream)

faces.show_faces(image_path, detected_faces)

# %%
image_path = './data/vision/personatriste.jpg'
image_stream = open(image_path, "rb")

attributes = ['age', 'emotion']
detected_faces = client.face.detect_with_stream(image = image_stream, return_face_attributes=attributes)

faces.show_face_attributes(image_path, detected_faces)

# %% [markdown]
# # En las siguientes no detectó las emociones.

# %%
image_path = './data/vision/personatriste2.jpg'
image_stream = open(image_path, "rb")

attributes = ['age', 'emotion']
detected_faces = client.face.detect_with_stream(image = image_stream, return_face_attributes=attributes)

faces.show_face_attributes(image_path, detected_faces)

# %%
image_path = './data/vision/persona3.png'
image_stream = open(image_path, "rb")

attributes = ['age', 'emotion']
detected_faces = client.face.detect_with_stream(image = image_stream, return_face_attributes=attributes)

faces.show_face_attributes(image_path, detected_faces)
